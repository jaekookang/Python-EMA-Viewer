# %% [markdown]
# # Test and view IEEE data
#
# ---
# - 2024-12-03 jkang first created

# %%
import os
import sys
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np
sys.path.insert(0, '..')
from mviewer import Viewer

# %%
example_file = '/home/jkang/dataset/ieee_db/Haskins_IEEE_Rate_Comparison_DB/M04/data/M04_B02_S44_R01_N.mat'
save_file = 'M04_B02_S44_R01_N.pkl'

# %%
mm = Viewer()
mm.load(example_file)
mm.mat2py(save_file=save_file)

# %%
mm.plot(channel_list=['AUDIO','TR', 'TB', 'TT'], show=True)
# Out:
# (<Figure size 800x400 with 4 Axes>,
#  array([<Axes: title={'left': 'AUDIO'}>, <Axes: title={'left': 'TR'}>,
#         <Axes: title={'left': 'TB'}>, <Axes: title={'left': 'TT'}>],
#        dtype=object))
